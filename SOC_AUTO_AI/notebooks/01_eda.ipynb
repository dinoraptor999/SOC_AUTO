# %% [markdown]
# # EDA
# Load and inspect the sample security events.

# %%
import pandas as pd
from pathlib import Path

path = Path.cwd() / 'dataset' / 'raw' / 'sample.jsonl'
events = pd.read_json(path, lines=True)
events.head()
