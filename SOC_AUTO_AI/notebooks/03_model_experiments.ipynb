# %% [markdown]
# # Model Experiments
# Run a small Isolation Forest experiment.

# %%
from sklearn.ensemble import IsolationForest
from src.features import build_feature_matrix
from src.utils import load_jsonl

records = load_jsonl('dataset/raw/sample.jsonl')
matrix, _, _ = build_feature_matrix(records)
model = IsolationForest(n_estimators=20, random_state=42).fit(matrix)
model.predict(matrix[:3])
