# %% [markdown]
# # Feature Engineering
# Inspect the normalized feature representation.

# %%
from src.features import extract_features

record = {'src_ip': '10.0.0.1', 'dst_ip': '8.8.8.8', 'src_port': 50000, 'dst_port': 22, 'protocol': 'tcp', 'event_type': 'auth', 'failed_count': 5, 'bytes': 2000}
extract_features(record)
